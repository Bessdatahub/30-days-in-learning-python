# %% [markdown]
# ##### A list is a mutable changeable sequence of items. Lists can contain elements of different data types including other lists
#
# ##### Lists are in [] brackets

# %%
Items = []

# %%
type(Items)
# Out:
# list

# %%
## List can contain multiple data types

Movies= ["Bluey", "Spider Man", "Devil", 24,True, 45.6]

Movies
# Out:
# ['Bluey', 'Spider Man', 'Devil', 24, True, 45.6]

# %%
list("Hello")
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
type(Movies)
# Out:
# list

# %% [markdown]
# ## List Functions

# %% [markdown]
# ##### 1. Indexing

# %%
Movies[:3+1]
# Out:
# ['Bluey', 'Spider Man', 'Devil', 24]

# %% [markdown]
# ##### 2.Slice notation can also be used to access portions of lists [start: stop: step size], the stop is not inclusive else +1

# %%
Movies[::2]
# Out:
# ['Bluey', 'Devil', True]

# %%
Movies[2:4]
# Out:
# ['Devil', 24]

# %% [markdown]
# ##### 3. Changing lists in an element

# %%
pack= ['sugar', 'wolves', 'biscuits','pencils','erasers']

pack[1]= 'plates'

pack
# Out:
# ['sugar', 'plates', 'biscuits', 'pencils', 'erasers']

# %%
pack[5]= 'chairs'
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pack[5]= 'chairs'
#
# IndexError: list assignment index out of range

# %% [markdown]
# #### 4. Adding elements to a list

# %% [markdown]
# ##### Append= Add elements to the end of the list and Insert= Add elements to a specific posi

# %%
States= ['Abia', 'Adamawa', 'Akwa-Ibom','Anambra']

States.append('Bauchi')

States
# Out:
# ['Abia', 'Adamawa', 'Akwa-Ibom', 'Anambra', 'Bauchi']

# %%
Capital = ['Umuahia', 'Yola', 'Bauchi', 'Awka']
Capital
# Out:
# ['Umuahia', 'Yola', 'Bauchi', 'Awka']

# %%
Capital.insert(2, 'Uyo')

Capital
# Out:
# ['Umuahia', 'Yola', 'Uyo', 'Bauchi', 'Awka']

# %% [markdown]
# ##### Combining and Repeating Lists, Lists can be combined using + and repeated using *

# %%
All= States + Capital
All
# Out:
# ['Abia',
#  'Adamawa',
#  'Akwa-Ibom',
#  'Anambra',
#  'Bauchi',
#  'Umuahia',
#  'Yola',
#  'Uyo',
#  'Bauchi',
#  'Awka']

# %%
States *3
# Out:
# ['Abia',
#  'Adamawa',
#  'Akwa-Ibom',
#  'Anambra',
#  'Bauchi',
#  'Abia',
#  'Adamawa',
#  'Akwa-Ibom',
#  'Anambra',
#  'Bauchi',
#  'Abia',
#  'Adamawa',
#  'Akwa-Ibom',
#  'Anambra',
#  'Bauchi']

# %% [markdown]
# ##### The delete keywords remove the elements based on the selected items on the sliicng while the remove method deletes the first occurrenceof the specified value in the list

# %%
Food= ['Yam', 'Eggs', 'Okra','Indomie','Egusi', 'Carrots']

# %%
del Food[-1]

Food
# Out:
# ['Yam', 'Eggs', 'Okra', 'Indomie', 'Egusi']

# %%
Food.remove('Egusi')

Food
# Out:
# ['Yam', 'Eggs', 'Okra', 'Indomie']

# %% [markdown]
# ##### Len,Sum,Min,Max Functions

# %%
Transactions = [2, 2.34, 5.678, 2.3456, 34, 23]

len(Transactions)
# Out:
# 6

# %%
sum(Transactions)
# Out:
# 69.3636

# %%
min(Transactions)
# Out:
# 2

# %%
max(Transactions)
# Out:
# 34

# %% [markdown]
# ##### Sort-This sort the original and Sorted_ This returns a sorted list but does not change the original

# %%
Transactions.sort()

Transactions
# Out:
# [2, 2.34, 2.3456, 5.678, 23, 34]

# %%
sorted(Transactions)
# Out:
# [2, 2.34, 2.3456, 5.678, 23, 34]

# %% [markdown]
# ##### Index: Returns the index of a specified value within a list (returns -1 if not found),
#
# ##### Reverse:Reverses the order of the list elements in place
#
# ##### Count:Counts the number of times a given value occurs in a list

# %%
Transactions.reverse()
Transactions
# Out:
# [34, 23, 5.678, 2.3456, 2.34, 2]

# %%
Transactions.index(23)
# Out:
# 1

# %%
Transactions.count(5.678)
# Out:
# 1

# %% [markdown]
# ##### Nested Lists

# %%
Alphabets= [['a', 'b', 'c'], ['d', 'e', 'f'],['g' 'h', 'i']]
Alphabets[2][-1]
# Out:
# 'i'

# %%
Alphabets[1].count('e')
# Out:
# 1

# %% [markdown]
# ### Copying a list
#
# ##### There are 3 different ways of copying a list: Variable Assignment .Copy() and deecopy()he

# %%
## Variable Assignmen:Copying a list via variable assignment creates a “view” of the list 
## Both variables point to the same object in memory 3.Changing an element in one list will result in a change to the other

List_1= ['Pear', 'Mango', 'PawPaw', 'Orange', 'Turkey']

List_2 = List_1

print(List_2)
# Out:
# ['Pear', 'Mango', 'PawPaw', 'Orange', 'Turkey']

# %%
List_1[-1] = 'Banana'
List_1
# Out:
# ['Pear', 'Mango', 'PawPaw', 'Orange', 'Banana']

# %%
List_2
# Out:
# ['Pear', 'Mango', 'PawPaw', 'Orange', 'Banana']

# %%
# Copying a list with the .copy() method creates a copy of the list
# Changes to entire elements (nested lists) will not carry over between original and copy
# Changes to individual elements within a nested list will still be reflected in both

List_3= List_1.copy()

List_3
# Out:
# ['Pear', 'Mango', 'PawPaw', 'Orange', 'Banana']

# %%
List_1[2] = 'Blue Berry'

List_3
# Out:
# ['Pear', 'Mango', 'PawPaw', 'Orange', 'Banana']

# %%
List_1
# Out:
# ['Pear', 'Mango', 'Blue Berry', 'Orange', 'Banana']

# %%
letter_1 = [['One', 'Two', 'Cat', 'Dog'],
           ['Cup', 'Car', 'Rat', 'Fit'],
           ['War', 'Bar', 'Fix', 'Rub']]

# %%
letter_2= letter_1.copy()

letter_2
# Out:
# [['One', 'Two', 'Cat', 'Dog'],
#  ['Cup', 'Car', 'Rat', 'Fit'],
#  ['War', 'Bar', 'Fix', 'Rub']]

# %%
letter_1[1]= ['Rob', 'Bub', 'lip', 'Tap']

letter_2
# Out:
# [['One', 'Two', 'Cat', 'Dog'],
#  ['Cup', 'Car', 'Rat', 'Fit'],
#  ['War', 'Bar', 'Fix', 'Rub']]

# %%
letter_1[0][1]= 'Owl'

letter_2
# Out:
# [['One', 'Owl', 'Cat', 'Dog'],
#  ['Cup', 'Car', 'Rat', 'Fit'],
#  ['War', 'Bar', 'Fix', 'Rub']]
