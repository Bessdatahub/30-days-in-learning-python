# %%
print("hello world")
# Out:
# hello world

# %%
## In python when writing a string(text) double quotes must be included

"Welcome to my python class"
# Out:
# 'Welcome to my python class'

# %%
## Without the use of quotes (Note that this will print an error)

Welcome to my python class
# Out:
#   Cell In[4], line 3
#     Welcome to my python class
#             ^
# SyntaxError: invalid syntax

# %%
## this will print an error and this is because of the single quotes mother's, to correct this use a double quotes/tripple quotes,\
'She is her mother's daughter'
# Out:
#   Cell In[14], line 2
#     'She is her mother's daughter'
#                                  ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
'''she is her mother's daugheter'''
# Out:
# "she is her mother's daugheter"

# %%
"she is her mother's daughter"
# Out:
# "she is her mother's daughter"

# %%
'She is her mother\'s daughter'
# Out:
# "She is her mother's daughter"

# %%
## Print a shopping list

print("-Gucci Bag \n-Prada Shoes \n-Tesla cars")
# Out:
# -Gucci Bag
# -Prada Shoes
# -Tesla cars

# %%
print("Today is Monday, \nOh I hate Mondaysssss")
# Out:
# Today is Monday,
# Oh I hate Mondaysssss

# %% [markdown]
# # Indentation
#
# ### Python uses indentation to define blocks of code

# %%
if 5 > 2:
    print("five is greater than two")
# Out:
# five is greater than two

# %% [markdown]
# # Variable
#
# ##### A variable is like a container it stores data in a program, a variable can be reused and manipulated it also stores different data types

# %%
Age = 27
# the varible here is Age and the dat type is interger.

print(Age)
# Out:
# 27

# %% [markdown]
# ## Input in python

# %%
user_name = input("What is your name :")
print(f"My name is {user_name}")
# Out:
# What is your name : Blessing John
# My name is Blessing John
