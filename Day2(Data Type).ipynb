# %% [markdown]
# ### Data Type
#
# Strings
# Float
# Integer
# Boolean

# %%
produvt= 'Procari Sweat'
price = 50.0
qty= 3
is_hot= False

# %%
type(is_hot)
# Out:
# bool

# %%
type(price)
# Out:
# float

# %%
age = '27'

type(age)
# Out:
# str

# %% [markdown]
# ## Operators
#
# ##### We have Arithmetic (+,-,*,/,//,%)
#
# ##### Comparison Operators (=,<,>, !=)
#
# ##### Logical Operators(And, OR, Not: The Not operator will reverse the result True becomes false and false True)

# %%
Is_raining = True

if not Is_raining:
    print("Dont go outside")
else: 
    print("It is not raining")
# Out:
# It is not raining

# %% [markdown]
# ##### Assignment Operator

# %%
Savings = 50

## Savings = Savings +100

Savings += 100

Savings
# Out:
# 150

# %% [markdown]
# ## Project
#
# ##### Create an ecommerce project that asks the user their name, what they want to buy and the quantities, also include the price in #)

# %%
Name= input("What is your name: ")

Products= input("What items are you buying: ")

Quantity = int(input("How many quantities: "))

price= int(input("At what price: "))

results= Quantity * price

print(f"Hi {Name}, your items are {Products} and the total fee is #{results}")
# Out:
# What is your name:  Ada
# What items are you buying:  fish
# How many quantities:  3
# At what price:  34
# Hi Ada, your items are fish and the total fee is #102
